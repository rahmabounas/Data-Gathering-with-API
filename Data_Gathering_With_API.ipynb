# %% [markdown]
# # NASA Public APIs Data Extraction
#
# ## Objective
#
# This project aims to practice accessing and using NASA's **public APIs** to retrieve, process, and export **space-related data**.
# Specifically, the project covers:
#
# - Obtaining and managing an **API key**.
# - Making authenticated **API requests**.
# - Transforming response data into a **pandas DataFrame**.
# - Exporting the results to a **CSV file** for further use.
#
# ---
#
# ## Setup and Instructions
#
# ### 1. Get Your API Key
#
# Before making any API calls:
#
# - Visit the [NASA API Portal](https://api.nasa.gov/).
# - Complete the registration form with your information.
# - Receive your **personal API key** via email.
# - Store the API key securely for future use.
#
# > ⚠️ **Important:** Your API key uniquely identifies you. Do not share it publicly.
#
# ---
#
# ### 2. Access NASA APIs
#
# - Authenticate your requests by including your API key.
# - Explore available endpoints to select the data you want to retrieve (e.g., images, planetary information, meteor data).
#
# ---
#
# ### 3. Data Handling
#
# - Fetch the response (typically in JSON format).
# - Convert the data into a structured **pandas DataFrame**.
# - Perform any necessary cleaning or preprocessing.
#
# ---
#
# ### 4. Export Results
#
# - Save the final DataFrame to a **CSV file** for sharing, analysis, or visualization.
#
# ---
#
# ## Technologies
#
# - **Python 3**
# - **pandas** for data manipulation
# - **requests** for HTTP API communication
#
# ---
#
# ## Preview
#
# ![NASA API Portal](https://i.imgur.com/hisTmpk.png)
#
# ---
#
# ## Notes
#
# - Respect NASA’s [API usage policies](https://api.nasa.gov/terms.html).
# - Monitor your API usage to stay within rate limits.
# - Consider using environment variables or `.env` files to manage sensitive information like API keys.
#
# ---
#
# ## References
#
# - [NASA APIs Documentation](https://api.nasa.gov/)
# - [pandas Official Site](https://pandas.pydata.org/)
# - [requests Official Documentation](https://requests.readthedocs.io/en/latest/)
#
# ---
#
# ## License
#
# This project is intended for educational purposes only.

# %%
# The objective  is to practice accessing and using NASA's public APIs to retrieve and manipulate space-related data.

# import libraries we need for this project
import requests
from dotenv import load_dotenv
import os
import json
from bs4 import BeautifulSoup
import pandas as pd

# Load the .env file manually with the correct path
dotenv_path = os.path.join(os.getcwd(), '.env')
load_dotenv(dotenv_path)

# Fetch the NASA API key
NASA_API_KEY = os.getenv("NASA_API_KEY")

# %%
# Http request to GET the data_APOD from the NASA API APOD (Astronomy Picture of the Day)
response = requests.get(f"https://api.nasa.gov/planetary/apod?api_key={NASA_API_KEY}")

# Check if the request was successful (status code 200)

if response.status_code == 200:

    # Parse the JSON response
    data_APOD = response.json()

    # Print the title and explanation of the Astronomy Picture of the Day
    print("Title:", data_APOD['title'])

    # Print the date of the image
    print("Date:", data_APOD['date'])

    # print the explanation of the image and make it pretty and readable
    explanation = data_APOD['explanation'].replace('\n', ' ').replace('  ', ' ')
    print("Explanation:", explanation)

    # Print the URL of the image
    print("Image URL:", data_APOD['url'])

else:

    # Print an error message if the request was not successful
    print("Error:", response.status_code, response.text)

# The code retrieves the Astronomy Picture of the Day (APOD) from NASA's API and prints its title, explanation, and image URL.

#make the image appear in my notebook first import the library needed to display images
from IPython.display import Image, display

# Display the image using the URL from the API response
display(Image(url=data_APOD['url']))
# Out:
# Title: IC 418: The Spirograph Nebula
# Date: 2025-04-27
# Explanation: What is creating the strange texture of IC 418? Dubbed the Spirograph Nebula for its resemblance to drawings from a cyclical drawing tool, planetary nebula IC 418 shows patterns that are not well understood. Perhaps they are related to chaotic winds from the variable central star, which changes brightness unpredictably in just a few hours. By contrast, evidence indicates that only a few million years ago, IC 418 was probably a well-understood star similar to our Sun. Only a few thousand years ago, IC 418 was probably a common red giant star. Since running out of nuclear fuel, though, the outer envelope has begun expanding outward leaving a hot remnant core destined to become a white-dwarf star, visible in the image center. The light from the central core excites surrounding atoms in the nebula causing them to glow. IC 418 lies about 2000 light-years away and spans 0.3 light-years across. This false-color image taken from the Hubble Space Telescope reveals the unusual details.
# Image URL: https://apod.nasa.gov/apod/image/2504/Spirograph_Hubble_960.jpg
# <img src="https://apod.nasa.gov/apod/image/2504/Spirograph_Hubble_960.jpg"/>

# %%
# HTTP request to get data_astr about the Asteroids - NeoWs (Near Earth Object Web Service)
response = requests.get(f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2023-10-01&end_date=2023-10-07&api_key={NASA_API_KEY}")

#check if the request was successful (status code 200)
if response.status_code == 200:

    # Parse the JSON response
    data_astr = response.json()

    # Print the number of asteroids
    print("Number of asteroids:", data_astr['element_count'])

    # Print the list of asteroids
    for date, asteroids in data_astr['near_earth_objects'].items():
        print(f"Date: {date}")
        for asteroid in asteroids:
            print(f"  Asteroid ID: {asteroid['id']}")
            print(f"  Asteroid Name: {asteroid['name']}")
            print(f"  The Minimal estimated diameter (kilometers): {asteroid['estimated_diameter']['kilometers']['estimated_diameter_min']}")
            print(f"  Absolute_magnitude (H): {asteroid['absolute_magnitude_h']}")
            print(f"  Relative Velocity (km/h): {asteroid['close_approach_data'][0]['relative_velocity']['kilometers_per_hour']}")
else:
    # Print an error message if the request was not successful
    print("Error:", response.status_code, response.text)
# Out:
# Number of asteroids: 189
# Date: 2023-10-01
#   Asteroid ID: 2137084
#   Asteroid Name: 137084 (1998 XS16)
#   The Minimal estimated diameter (kilometers): 1.3444819516
#   Absolute_magnitude (H): 16.48
#   Relative Velocity (km/h): 64873.2160143983
#   Asteroid ID: 2252399
#   Asteroid Name: 252399 (2001 TX44)
#   The Minimal estimated diameter (kilometers): 0.3487827332
#   Absolute_magnitude (H): 19.41
#   Relative Velocity (km/h): 47425.552833141
#   Asteroid ID: 3342645
#   Asteroid Name: (2006 SG7)
#   The Minimal estimated diameter (kilometers): 0.0718712133
#   Absolute_magnitude (H): 22.84
#   Relative Velocity (km/h): 40346.826106311
#   Asteroid ID: 3451020
#   Asteroid Name: (2009 EG3)
#   The Minimal estimated diameter (kilometers): 0.1453968429
#   Absolute_magnitude (H): 21.31
#   Relative Velocity (km/h): 71098.0109047015
#   Asteroid ID: 3606252
#   Asteroid Name: (2012 OO)
#   The Minimal estimated diameter (kilometers): 0.1979497587
#   Absolute_magnitude (H): 20.64
#   Relative Velocity (km/h): 33991.7291708756
#   Asteroid ID: 3740047
#   Asteroid Name: (2016 AM165)
#   The Minimal estimated diameter (kilometers): 0.0305179233
#   Absolute_magnitude (H): 24.7
#   Relative Velocity (km/h): 21746.7219087179
#   Asteroid ID: 3888755
#   Asteroid Name: (2019 UQ12)
#   The Minimal estimated diameter (kilometers): 0.046190746
#   Absolute_magnitude (H): 23.8
#   Relative Velocity (km/h): 64516.5575776706
#   Asteroid ID: 54016425
#   Asteroid Name: (2020 FW6)
#   The Minimal estimated diameter (kilometers): 0.0603330078
#   Absolute_magnitude (H): 23.22
#   Relative Velocity (km/h): 46657.9212968621
#   Asteroid ID: 54016634
#   Asteroid Name: (2020 HO2)
#   The Minimal estimated diameter (kilometers): 0.0366906138
#   Absolute_magnitude (H): 24.3
#   Relative Velocity (km/h): 45466.0186505674
#   Asteroid ID: 54217963
#   Asteroid Name: (2021 VA6)
#   The Minimal estimated diameter (kilometers): 0.0045139316
#   Absolute_magnitude (H): 28.85
#   Relative Velocity (km/h): 31894.7763409622
#   Asteroid ID: 54244779
#   Asteroid Name: (2022 CB1)
#   The Minimal estimated diameter (kilometers): 0.014878357
#   Absolute_magnitude (H): 26.26
#   Relative Velocity (km/h): 62355.3826068403
#   Asteroid ID: 54304629
#   Asteroid Name: (2022 SW)
#   The Minimal estimated diameter (kilometers): 0.0249203981
#   Absolute_magnitude (H): 25.14
#   Relative Velocity (km/h): 44784.2590807882
#   Asteroid ID: 54380190
#   Asteroid Name: (2023 QB10)
#   The Minimal estimated diameter (kilometers): 0.1118291378
#   Absolute_magnitude (H): 21.88
#   Relative Velocity (km/h): 16732.0434664351
#   Asteroid ID: 54383295
#   Asteroid Name: (2023 RE11)
#   The Minimal estimated diameter (kilometers): 0.0225193047
#   Absolute_magnitude (H): 25.36
#   Relative Velocity (km/h): 34505.6659429336
#   Asteroid ID: 54385248
#   Asteroid Name: (2023 SW1)
#   The Minimal estimated diameter (kilometers): 0.0417402433
#   Absolute_magnitude (H): 24.02
#   Relative Velocity (km/h): 28243.2311570753
#   Asteroid ID: 54385794
#   Asteroid Name: (2023 SY2)
#   The Minimal estimated diameter (kilometers): 0.0154367182
#   Absolute_magnitude (H): 26.18
#   Relative Velocity (km/h): 35684.2487171859
#   Asteroid ID: 54390661
#   Asteroid Name: (2023 TJ)
#   The Minimal estimated diameter (kilometers): 0.024019003
#   Absolute_magnitude (H): 25.22
#   Relative Velocity (km/h): 83572.0667600648
#   Asteroid ID: 54391043
#   Asteroid Name: (2023 TO2)
#   The Minimal estimated diameter (kilometers): 0.013018321
#   Absolute_magnitude (H): 26.55
#   Relative Velocity (km/h): 43535.427013355
#   Asteroid ID: 54397459
#   Asteroid Name: (2023 UC4)
#   The Minimal estimated diameter (kilometers): 0.0279611466
#   Absolute_magnitude (H): 24.89
#   Relative Velocity (km/h): 40131.9353464456
#   Asteroid ID: 54428637
#   Asteroid Name: (2024 DT1)
#   The Minimal estimated diameter (kilometers): 0.0973991073
#   Absolute_magnitude (H): 22.18
#   Relative Velocity (km/h): 38643.2624168996
#   Asteroid ID: 54429759
#   Asteroid Name: (2024 EK1)
#   The Minimal estimated diameter (kilometers): 0.1092835959
#   Absolute_magnitude (H): 21.93
#   Relative Velocity (km/h): 57582.8122273495
#   Asteroid ID: 54490134
#   Asteroid Name: (2024 TX9)
#   The Minimal estimated diameter (kilometers): 0.0140784543
#   Absolute_magnitude (H): 26.38
#   Relative Velocity (km/h): 62761.6611957488
#   Asteroid ID: 54507392
#   Asteroid Name: (2024 YB)
#   The Minimal estimated diameter (kilometers): 0.0207278843
#   Absolute_magnitude (H): 25.54
#   Relative Velocity (km/h): 11450.6707227882
# Date: 2023-10-02
#   Asteroid ID: 2105140
#   Asteroid Name: 105140 (2000 NL10)
#   The Minimal estimated diameter (kilometers): 1.8904055193
#   Absolute_magnitude (H): 15.74
#   Relative Velocity (km/h): 140926.7920826668
#   Asteroid ID: 2405762
#   Asteroid Name: 405762 (2005 YO180)
#   The Minimal estimated diameter (kilometers): 0.2325706875
#   Absolute_magnitude (H): 20.29
#   Relative Velocity (km/h): 77196.7239248135
#   Asteroid ID: 2488474
#   Asteroid Name: 488474 (1999 HD1)
#   The Minimal estimated diameter (kilometers): 0.229379698
#   Absolute_magnitude (H): 20.32
#   Relative Velocity (km/h): 62121.1321729156
#   Asteroid ID: 3423321
#   Asteroid Name: (2008 PW4)
#   The Minimal estimated diameter (kilometers): 0.0872077289
#   Absolute_magnitude (H): 22.42
#   Relative Velocity (km/h): 19601.0326250889
#   Asteroid ID: 3761035
#   Asteroid Name: (2016 TB57)
#   The Minimal estimated diameter (kilometers): 0.0160160338
#   Absolute_magnitude (H): 26.1
#   Relative Velocity (km/h): 47850.5104193084
#   Asteroid ID: 3781908
#   Asteroid Name: (2017 SN17)
#   The Minimal estimated diameter (kilometers): 0.0742258153
#   Absolute_magnitude (H): 22.77
#   Relative Velocity (km/h): 45046.1879319467
#   Asteroid ID: 54054714
#   Asteroid Name: (2020 SV6)
#   The Minimal estimated diameter (kilometers): 0.046190746
#   Absolute_magnitude (H): 23.8
#   Relative Velocity (km/h): 52427.7743783015
#   Asteroid ID: 54055076
#   Asteroid Name: (2020 TE2)
#   The Minimal estimated diameter (kilometers): 0.0149470324
#   Absolute_magnitude (H): 26.25
#   Relative Velocity (km/h): 61186.2638547492
#   Asteroid ID: 54087416
#   Asteroid Name: (2020 VF)
#   The Minimal estimated diameter (kilometers): 0.040230458
#   Absolute_magnitude (H): 24.1
#   Relative Velocity (km/h): 74455.5950844728
#   Asteroid ID: 54316566
#   Asteroid Name: (2022 TS2)
#   The Minimal estimated diameter (kilometers): 0.0325502986
#   Absolute_magnitude (H): 24.56
#   Relative Velocity (km/h): 103058.7083468615
#   Asteroid ID: 54377847
#   Asteroid Name: (2023 QU2)
#   The Minimal estimated diameter (kilometers): 0.1700415193
#   Absolute_magnitude (H): 20.97
#   Relative Velocity (km/h): 15709.4022120355
#   Asteroid ID: 54377968
#   Asteroid Name: (2023 QB4)
#   The Minimal estimated diameter (kilometers): 0.2658
#   Absolute_magnitude (H): 20.0
#   Relative Velocity (km/h): 50052.0996269068
#   Asteroid ID: 54378341
#   Asteroid Name: (2023 QE5)
#   The Minimal estimated diameter (kilometers): 0.0365220357
#   Absolute_magnitude (H): 24.31
#   Relative Velocity (km/h): 21071.9137527626
#   Asteroid ID: 54385240
#   Asteroid Name: (2023 SO1)
#   The Minimal estimated diameter (kilometers): 0.0287445144
#   Absolute_magnitude (H): 24.83
#   Relative Velocity (km/h): 25313.8569079984
#   Asteroid ID: 54390615
#   Asteroid Name: (2023 TB)
#   The Minimal estimated diameter (kilometers): 0.0115492818
#   Absolute_magnitude (H): 26.81
#   Relative Velocity (km/h): 47825.4918283171
#   Asteroid ID: 54390824
#   Asteroid Name: (2023 TS)
#   The Minimal estimated diameter (kilometers): 0.009830033
#   Absolute_magnitude (H): 27.16
#   Relative Velocity (km/h): 63667.1571477725
#   Asteroid ID: 54391010
#   Asteroid Name: (2023 TF1)
#   The Minimal estimated diameter (kilometers): 0.0250354255
#   Absolute_magnitude (H): 25.13
#   Relative Velocity (km/h): 43954.5230335818
#   Asteroid ID: 54391033
#   Asteroid Name: (2023 TD2)
#   The Minimal estimated diameter (kilometers): 0.0298232505
#   Absolute_magnitude (H): 24.75
#   Relative Velocity (km/h): 48054.4635237872
#   Asteroid ID: 54392426
#   Asteroid Name: (2023 TA5)
#   The Minimal estimated diameter (kilometers): 0.0199781365
#   Absolute_magnitude (H): 25.62
#   Relative Velocity (km/h): 21763.0834766034
#   Asteroid ID: 54392432
#   Asteroid Name: (2023 TG5)
#   The Minimal estimated diameter (kilometers): 0.011982708
#   Absolute_magnitude (H): 26.73
#   Relative Velocity (km/h): 18468.1091589744
#   Asteroid ID: 54392651
#   Asteroid Name: (2023 TV6)
#   The Minimal estimated diameter (kilometers): 0.0445199816
#   Absolute_magnitude (H): 23.88
#   Relative Velocity (km/h): 33967.5477778096
#   Asteroid ID: 54395027
#   Asteroid Name: (2023 UJ)
#   The Minimal estimated diameter (kilometers): 0.0145396843
#   Absolute_magnitude (H): 26.31
#   Relative Velocity (km/h): 23240.9373739735
#   Asteroid ID: 54395893
#   Asteroid Name: (2023 UU)
#   The Minimal estimated diameter (kilometers): 0.0552783379
#   Absolute_magnitude (H): 23.41
#   Relative Velocity (km/h): 19383.3649798029
#   Asteroid ID: 54405060
#   Asteroid Name: (2023 VX8)
#   The Minimal estimated diameter (kilometers): 0.042320908
#   Absolute_magnitude (H): 23.99
#   Relative Velocity (km/h): 33686.6151853027
#   Asteroid ID: 54482429
#   Asteroid Name: (2024 SO2)
#   The Minimal estimated diameter (kilometers): 0.0069912523
#   Absolute_magnitude (H): 27.9
#   Relative Velocity (km/h): 57001.9013735497
# Date: 2023-10-03
#   Asteroid ID: 2221980
#   Asteroid Name: 221980 (1996 EO)
#   The Minimal estimated diameter (kilometers): 0.4004561582
#   Absolute_magnitude (H): 19.11
#   Relative Velocity (km/h): 46560.2380556378
#   Asteroid ID: 2349507
#   Asteroid Name: 349507 (2008 QY)
#   The Minimal estimated diameter (kilometers): 0.5303407233
#   Absolute_magnitude (H): 18.5
#   Relative Velocity (km/h): 75456.7796296066
#   Asteroid ID: 2366470
#   Asteroid Name: 366470 (2002 FD)
#   The Minimal estimated diameter (kilometers): 0.3377185972
#   Absolute_magnitude (H): 19.48
#   Relative Velocity (km/h): 41968.8282591158
#   Asteroid ID: 3136724
#   Asteroid Name: (2002 RS129)
#   The Minimal estimated diameter (kilometers): 0.0695913044
#   Absolute_magnitude (H): 22.91
#   Relative Velocity (km/h): 30181.7764770804
#   Asteroid ID: 3137738
#   Asteroid Name: (2002 TA60)
#   The Minimal estimated diameter (kilometers): 0.1740022951
#   Absolute_magnitude (H): 20.92
#   Relative Velocity (km/h): 100877.0921909683
#   Asteroid ID: 3634614
#   Asteroid Name: (2013 GT66)
#   The Minimal estimated diameter (kilometers): 0.0242412481
#   Absolute_magnitude (H): 25.2
#   Relative Velocity (km/h): 60171.6516711156
#   Asteroid ID: 3699892
#   Asteroid Name: (2014 WZ365)
#   The Minimal estimated diameter (kilometers): 0.0167708462
#   Absolute_magnitude (H): 26.0
#   Relative Velocity (km/h): 56420.3150753688
#   Asteroid ID: 3728901
#   Asteroid Name: (2015 TA)
#   The Minimal estimated diameter (kilometers): 0.1289896833
#   Absolute_magnitude (H): 21.57
#   Relative Velocity (km/h): 50652.4951778141
#   Asteroid ID: 3759289
#   Asteroid Name: (2016 RL20)
#   The Minimal estimated diameter (kilometers): 0.0513517179
#   Absolute_magnitude (H): 23.57
#   Relative Velocity (km/h): 40828.597948539
#   Asteroid ID: 3789747
#   Asteroid Name: (2017 WD28)
#   The Minimal estimated diameter (kilometers): 0.0192555078
#   Absolute_magnitude (H): 25.7
#   Relative Velocity (km/h): 37222.489153206
#   Asteroid ID: 3791345
#   Asteroid Name: (2017 XV60)
#   The Minimal estimated diameter (kilometers): 0.0183888672
#   Absolute_magnitude (H): 25.8
#   Relative Velocity (km/h): 41385.506353456
#   Asteroid ID: 3956451
#   Asteroid Name: (2019 YS3)
#   The Minimal estimated diameter (kilometers): 0.0315177333
#   Absolute_magnitude (H): 24.63
#   Relative Velocity (km/h): 17341.1128522013
#   Asteroid ID: 54016766
#   Asteroid Name: (2020 HT6)
#   The Minimal estimated diameter (kilometers): 0.0305179233
#   Absolute_magnitude (H): 24.7
#   Relative Velocity (km/h): 24582.6073522747
#   Asteroid ID: 54054505
#   Asteroid Name: (2020 SP1)
#   The Minimal estimated diameter (kilometers): 0.063760979
#   Absolute_magnitude (H): 23.1
#   Relative Velocity (km/h): 99192.4158630694
#   Asteroid ID: 54131386
#   Asteroid Name: (2021 EX3)
#   The Minimal estimated diameter (kilometers): 0.0287445144
#   Absolute_magnitude (H): 24.83
#   Relative Velocity (km/h): 33947.6983705489
#   Asteroid ID: 54184284
#   Asteroid Name: (2021 PF7)
#   The Minimal estimated diameter (kilometers): 0.0072871041
#   Absolute_magnitude (H): 27.81
#   Relative Velocity (km/h): 20189.5791455947
#   Asteroid ID: 54291608
#   Asteroid Name: (2022 OZ1)
#   The Minimal estimated diameter (kilometers): 0.0513517179
#   Absolute_magnitude (H): 23.57
#   Relative Velocity (km/h): 91239.6500188769
#   Asteroid ID: 54354418
#   Asteroid Name: (2023 GW2)
#   The Minimal estimated diameter (kilometers): 0.0170826395
#   Absolute_magnitude (H): 25.96
#   Relative Velocity (km/h): 32965.7434928194
#   Asteroid ID: 54378774
#   Asteroid Name: (2023 QT6)
#   The Minimal estimated diameter (kilometers): 0.0494942761
#   Absolute_magnitude (H): 23.65
#   Relative Velocity (km/h): 19358.3019285
#   Asteroid ID: 54384203
#   Asteroid Name: (2023 RF16)
#   The Minimal estimated diameter (kilometers): 0.0197040262
#   Absolute_magnitude (H): 25.65
#   Relative Velocity (km/h): 19664.9800828219
#   Asteroid ID: 54384766
#   Asteroid Name: (2023 RS21)
#   The Minimal estimated diameter (kilometers): 0.0483676488
#   Absolute_magnitude (H): 23.7
#   Relative Velocity (km/h): 13364.7765115458
#   Asteroid ID: 54390660
#   Asteroid Name: (2023 TH)
#   The Minimal estimated diameter (kilometers): 0.0110294785
#   Absolute_magnitude (H): 26.91
#   Relative Velocity (km/h): 28662.3878505242
#   Asteroid ID: 54390828
#   Asteroid Name: (2023 TY)
#   The Minimal estimated diameter (kilometers): 0.0039314701
#   Absolute_magnitude (H): 29.15
#   Relative Velocity (km/h): 47274.7545572562
#   Asteroid ID: 54393138
#   Asteroid Name: (2023 TU8)
#   The Minimal estimated diameter (kilometers): 0.0138214936
#   Absolute_magnitude (H): 26.42
#   Relative Velocity (km/h): 13355.2668107945
#   Asteroid ID: 54395900
#   Asteroid Name: (2023 UA1)
#   The Minimal estimated diameter (kilometers): 0.0328514828
#   Absolute_magnitude (H): 24.54
#   Relative Velocity (km/h): 25347.2662359006
#   Asteroid ID: 54454240
#   Asteroid Name: (2024 MD1)
#   The Minimal estimated diameter (kilometers): 0.0180532326
#   Absolute_magnitude (H): 25.84
#   Relative Velocity (km/h): 26689.5165707607
# Date: 2023-10-04
#   Asteroid ID: 2518635
#   Asteroid Name: 518635 (2008 HO3)
#   The Minimal estimated diameter (kilometers): 0.6173834405
#   Absolute_magnitude (H): 18.17
#   Relative Velocity (km/h): 50318.7462375181
#   Asteroid ID: 3648629
#   Asteroid Name: (2013 SC20)
#   The Minimal estimated diameter (kilometers): 0.0864082036
#   Absolute_magnitude (H): 22.44
#   Relative Velocity (km/h): 35943.0301319363
#   Asteroid ID: 3730326
#   Asteroid Name: (2015 TT178)
#   The Minimal estimated diameter (kilometers): 0.1716148941
#   Absolute_magnitude (H): 20.95
#   Relative Velocity (km/h): 86970.2379674983
#   Asteroid ID: 3829483
#   Asteroid Name: (2018 RT7)
#   The Minimal estimated diameter (kilometers): 0.0676947481
#   Absolute_magnitude (H): 22.97
#   Relative Velocity (km/h): 34202.2071228738
#   Asteroid ID: 3841618
#   Asteroid Name: (2019 HJ3)
#   The Minimal estimated diameter (kilometers): 0.0365220357
#   Absolute_magnitude (H): 24.31
#   Relative Velocity (km/h): 41162.4416759915
#   Asteroid ID: 54205444
#   Asteroid Name: (2021 TD7)
#   The Minimal estimated diameter (kilometers): 0.0123752784
#   Absolute_magnitude (H): 26.66
#   Relative Velocity (km/h): 52380.0746375915
#   Asteroid ID: 54265773
#   Asteroid Name: (2022 FX1)
#   The Minimal estimated diameter (kilometers): 0.0185590173
#   Absolute_magnitude (H): 25.78
#   Relative Velocity (km/h): 35716.9680621602
#   Asteroid ID: 54292217
#   Asteroid Name: (2022 OC3)
#   The Minimal estimated diameter (kilometers): 0.0056306039
#   Absolute_magnitude (H): 28.37
#   Relative Velocity (km/h): 11431.4620109647
#   Asteroid ID: 54312818
#   Asteroid Name: (2022 SL49)
#   The Minimal estimated diameter (kilometers): 0.0712122941
#   Absolute_magnitude (H): 22.86
#   Relative Velocity (km/h): 39091.1634111301
#   Asteroid ID: 54376554
#   Asteroid Name: (2023 OJ6)
#   The Minimal estimated diameter (kilometers): 0.1899131235
#   Absolute_magnitude (H): 20.73
#   Relative Velocity (km/h): 17820.9057834784
#   Asteroid ID: 54377955
#   Asteroid Name: (2023 QO3)
#   The Minimal estimated diameter (kilometers): 0.1231841913
#   Absolute_magnitude (H): 21.67
#   Relative Velocity (km/h): 9113.5439394267
#   Asteroid ID: 54380201
#   Asteroid Name: (2023 RZ)
#   The Minimal estimated diameter (kilometers): 0.052547853
#   Absolute_magnitude (H): 23.52
#   Relative Velocity (km/h): 37737.1056698528
#   Asteroid ID: 54380898
#   Asteroid Name: (2023 RS2)
#   The Minimal estimated diameter (kilometers): 0.0415484643
#   Absolute_magnitude (H): 24.03
#   Relative Velocity (km/h): 11573.9977664364
#   Asteroid ID: 54383294
#   Asteroid Name: (2023 RC11)
#   The Minimal estimated diameter (kilometers): 0.035200998
#   Absolute_magnitude (H): 24.39
#   Relative Velocity (km/h): 18636.9670590821
#   Asteroid ID: 54384755
#   Asteroid Name: (2023 RN21)
#   The Minimal estimated diameter (kilometers): 0.0269497646
#   Absolute_magnitude (H): 24.97
#   Relative Velocity (km/h): 28461.1546154895
#   Asteroid ID: 54392936
#   Asteroid Name: (2023 RJ69)
#   The Minimal estimated diameter (kilometers): 0.0788052183
#   Absolute_magnitude (H): 22.64
#   Relative Velocity (km/h): 5787.2378405814
#   Asteroid ID: 54387380
#   Asteroid Name: (2023 SN6)
#   The Minimal estimated diameter (kilometers): 0.0197949759
#   Absolute_magnitude (H): 25.64
#   Relative Velocity (km/h): 30583.2868188509
#   Asteroid ID: 54390629
#   Asteroid Name: (2023 TC)
#   The Minimal estimated diameter (kilometers): 0.0133830462
#   Absolute_magnitude (H): 26.49
#   Relative Velocity (km/h): 26562.107092237
#   Asteroid ID: 54391018
#   Asteroid Name: (2023 TO1)
#   The Minimal estimated diameter (kilometers): 0.0337718597
#   Absolute_magnitude (H): 24.48
#   Relative Velocity (km/h): 50238.6360943561
#   Asteroid ID: 54391028
#   Asteroid Name: (2023 TW1)
#   The Minimal estimated diameter (kilometers): 0.0313729225
#   Absolute_magnitude (H): 24.64
#   Relative Velocity (km/h): 71387.2808768437
#   Asteroid ID: 54391039
#   Asteroid Name: (2023 TJ2)
#   The Minimal estimated diameter (kilometers): 0.0169260249
#   Absolute_magnitude (H): 25.98
#   Relative Velocity (km/h): 56697.6370847159
#   Asteroid ID: 54392419
#   Asteroid Name: (2023 TN4)
#   The Minimal estimated diameter (kilometers): 0.0182202771
#   Absolute_magnitude (H): 25.82
#   Relative Velocity (km/h): 23131.1058473705
#   Asteroid ID: 54393145
#   Asteroid Name: (2023 TA9)
#   The Minimal estimated diameter (kilometers): 0.0124897854
#   Absolute_magnitude (H): 26.64
#   Relative Velocity (km/h): 20844.3500509024
#   Asteroid ID: 54394001
#   Asteroid Name: (2023 TT19)
#   The Minimal estimated diameter (kilometers): 0.0614546821
#   Absolute_magnitude (H): 23.18
#   Relative Velocity (km/h): 45112.8046100378
#   Asteroid ID: 54395026
#   Asteroid Name: (2023 TB23)
#   The Minimal estimated diameter (kilometers): 0.0799015081
#   Absolute_magnitude (H): 22.61
#   Relative Velocity (km/h): 20062.5162372871
#   Asteroid ID: 54395897
#   Asteroid Name: (2023 UX)
#   The Minimal estimated diameter (kilometers): 0.0283501249
#   Absolute_magnitude (H): 24.86
#   Relative Velocity (km/h): 20106.8107455375
#   Asteroid ID: 54396396
#   Asteroid Name: (2023 UT1)
#   The Minimal estimated diameter (kilometers): 0.0141434375
#   Absolute_magnitude (H): 26.37
#   Relative Velocity (km/h): 29952.5452781062
#   Asteroid ID: 54441078
#   Asteroid Name: (2024 JA7)
#   The Minimal estimated diameter (kilometers): 0.0187307418
#   Absolute_magnitude (H): 25.76
#   Relative Velocity (km/h): 17983.7805509024
#   Asteroid ID: 54489181
#   Asteroid Name: (2024 TV6)
#   The Minimal estimated diameter (kilometers): 0.0439091446
#   Absolute_magnitude (H): 23.91
#   Relative Velocity (km/h): 31041.2713314618
# Date: 2023-10-05
#   Asteroid ID: 3607823
#   Asteroid Name: (2012 QL14)
#   The Minimal estimated diameter (kilometers): 0.0337718597
#   Absolute_magnitude (H): 24.48
#   Relative Velocity (km/h): 55387.6495847312
#   Asteroid ID: 3702706
#   Asteroid Name: (2014 YS)
#   The Minimal estimated diameter (kilometers): 0.0334622374
#   Absolute_magnitude (H): 24.5
#   Relative Velocity (km/h): 27998.1320976973
#   Asteroid ID: 3774691
#   Asteroid Name: (2017 KZ2)
#   The Minimal estimated diameter (kilometers): 0.02658
#   Absolute_magnitude (H): 25.0
#   Relative Velocity (km/h): 81359.3885619841
#   Asteroid ID: 3785769
#   Asteroid Name: (2017 TJ4)
#   The Minimal estimated diameter (kilometers): 0.0242412481
#   Absolute_magnitude (H): 25.2
#   Relative Velocity (km/h): 53936.2197661763
#   Asteroid ID: 3795062
#   Asteroid Name: (2017 YX4)
#   The Minimal estimated diameter (kilometers): 0.0492668706
#   Absolute_magnitude (H): 23.66
#   Relative Velocity (km/h): 28690.9306987609
#   Asteroid ID: 3840696
#   Asteroid Name: (2019 FV)
#   The Minimal estimated diameter (kilometers): 0.0425162524
#   Absolute_magnitude (H): 23.98
#   Relative Velocity (km/h): 29408.0540511395
#   Asteroid ID: 3843679
#   Asteroid Name: (2019 QO5)
#   The Minimal estimated diameter (kilometers): 0.0474848397
#   Absolute_magnitude (H): 23.74
#   Relative Velocity (km/h): 33886.3719209783
#   Asteroid ID: 3989456
#   Asteroid Name: (2020 CW)
#   The Minimal estimated diameter (kilometers): 0.0008176265
#   Absolute_magnitude (H): 32.56
#   Relative Velocity (km/h): 69659.3138414285
#   Asteroid ID: 54087658
#   Asteroid Name: (2020 VW1)
#   The Minimal estimated diameter (kilometers): 0.0058150704
#   Absolute_magnitude (H): 28.3
#   Relative Velocity (km/h): 61355.4108691399
#   Asteroid ID: 54088822
#   Asteroid Name: (2020 WY)
#   The Minimal estimated diameter (kilometers): 0.0152951935
#   Absolute_magnitude (H): 26.2
#   Relative Velocity (km/h): 56215.4415623521
#   Asteroid ID: 54186663
#   Asteroid Name: (2021 PN26)
#   The Minimal estimated diameter (kilometers): 0.2262324906
#   Absolute_magnitude (H): 20.35
#   Relative Velocity (km/h): 82676.459302618
#   Asteroid ID: 54202334
#   Asteroid Name: (2021 TF1)
#   The Minimal estimated diameter (kilometers): 0.0174805453
#   Absolute_magnitude (H): 25.91
#   Relative Velocity (km/h): 47358.0125928979
#   Asteroid ID: 54231259
#   Asteroid Name: (2021 YB)
#   The Minimal estimated diameter (kilometers): 0.0083282735
#   Absolute_magnitude (H): 27.52
#   Relative Velocity (km/h): 16840.8055127065
#   Asteroid ID: 54308040
#   Asteroid Name: (2022 SY10)
#   The Minimal estimated diameter (kilometers): 0.0112345318
#   Absolute_magnitude (H): 26.87
#   Relative Velocity (km/h): 65204.5121845042
#   Asteroid ID: 54379680
#   Asteroid Name: (2023 QC8)
#   The Minimal estimated diameter (kilometers): 0.0308003021
#   Absolute_magnitude (H): 24.68
#   Relative Velocity (km/h): 22742.0588134825
#   Asteroid ID: 54381685
#   Asteroid Name: (2023 RP5)
#   The Minimal estimated diameter (kilometers): 0.040978398
#   Absolute_magnitude (H): 24.06
#   Relative Velocity (km/h): 31687.3084769206
#   Asteroid ID: 54382085
#   Asteroid Name: (2023 RJ6)
#   The Minimal estimated diameter (kilometers): 0.0356906927
#   Absolute_magnitude (H): 24.36
#   Relative Velocity (km/h): 25815.25147559
#   Asteroid ID: 54383286
#   Asteroid Name: (2023 RF10)
#   The Minimal estimated diameter (kilometers): 0.0200703514
#   Absolute_magnitude (H): 25.61
#   Relative Velocity (km/h): 20835.6308417098
#   Asteroid ID: 54390630
#   Asteroid Name: (2023 TD)
#   The Minimal estimated diameter (kilometers): 0.0101054342
#   Absolute_magnitude (H): 27.1
#   Relative Velocity (km/h): 28804.117835166
#   Asteroid ID: 54390829
#   Asteroid Name: (2023 TZ)
#   The Minimal estimated diameter (kilometers): 0.0385971268
#   Absolute_magnitude (H): 24.19
#   Relative Velocity (km/h): 57106.133725725
#   Asteroid ID: 54391012
#   Asteroid Name: (2023 TH1)
#   The Minimal estimated diameter (kilometers): 0.0274507982
#   Absolute_magnitude (H): 24.93
#   Relative Velocity (km/h): 64172.2519203937
#   Asteroid ID: 54391027
#   Asteroid Name: (2023 TY1)
#   The Minimal estimated diameter (kilometers): 0.0138852907
#   Absolute_magnitude (H): 26.41
#   Relative Velocity (km/h): 21610.9126703048
#   Asteroid ID: 54391042
#   Asteroid Name: (2023 TN2)
#   The Minimal estimated diameter (kilometers): 0.0063760979
#   Absolute_magnitude (H): 28.1
#   Relative Velocity (km/h): 26015.2437593419
#   Asteroid ID: 54392068
#   Asteroid Name: (2023 TN3)
#   The Minimal estimated diameter (kilometers): 0.008366715
#   Absolute_magnitude (H): 27.51
#   Relative Velocity (km/h): 12733.4386487664
#   Asteroid ID: 54392075
#   Asteroid Name: (2023 TW3)
#   The Minimal estimated diameter (kilometers): 0.0133830462
#   Absolute_magnitude (H): 26.49
#   Relative Velocity (km/h): 35646.6470868676
#   Asteroid ID: 54392430
#   Asteroid Name: (2023 TE5)
#   The Minimal estimated diameter (kilometers): 0.0130784109
#   Absolute_magnitude (H): 26.54
#   Relative Velocity (km/h): 26607.1437578276
#   Asteroid ID: 54393150
#   Asteroid Name: (2023 TW9)
#   The Minimal estimated diameter (kilometers): 0.0421264611
#   Absolute_magnitude (H): 24.0
#   Relative Velocity (km/h): 45603.9937294427
#   Asteroid ID: 54454874
#   Asteroid Name: (2024 MM1)
#   The Minimal estimated diameter (kilometers): 0.0150853356
#   Absolute_magnitude (H): 26.23
#   Relative Velocity (km/h): 8730.4029588411
#   Asteroid ID: 54491558
#   Asteroid Name: (2024 TP17)
#   The Minimal estimated diameter (kilometers): 0.0382432662
#   Absolute_magnitude (H): 24.21
#   Relative Velocity (km/h): 62189.6751844121
# Date: 2023-10-06
#   Asteroid ID: 3582137
#   Asteroid Name: (2011 UG20)
#   The Minimal estimated diameter (kilometers): 0.1369477737
#   Absolute_magnitude (H): 21.44
#   Relative Velocity (km/h): 117590.0017531424
#   Asteroid ID: 3604990
#   Asteroid Name: (2012 KP24)
#   The Minimal estimated diameter (kilometers): 0.0136318556
#   Absolute_magnitude (H): 26.45
#   Relative Velocity (km/h): 29175.6055399241
#   Asteroid ID: 3610529
#   Asteroid Name: (2012 TR139)
#   The Minimal estimated diameter (kilometers): 0.1708263953
#   Absolute_magnitude (H): 20.96
#   Relative Velocity (km/h): 100107.3794017702
#   Asteroid ID: 3782014
#   Asteroid Name: (2017 SX20)
#   The Minimal estimated diameter (kilometers): 0.0394961694
#   Absolute_magnitude (H): 24.14
#   Relative Velocity (km/h): 52099.0613544863
#   Asteroid ID: 54016296
#   Asteroid Name: (2020 FS2)
#   The Minimal estimated diameter (kilometers): 0.0363542322
#   Absolute_magnitude (H): 24.32
#   Relative Velocity (km/h): 33494.1146844843
#   Asteroid ID: 54292683
#   Asteroid Name: (2022 OB5)
#   The Minimal estimated diameter (kilometers): 0.004290965
#   Absolute_magnitude (H): 28.96
#   Relative Velocity (km/h): 4917.462371602
#   Asteroid ID: 54382568
#   Asteroid Name: (2023 RX7)
#   The Minimal estimated diameter (kilometers): 0.0527904029
#   Absolute_magnitude (H): 23.51
#   Relative Velocity (km/h): 51216.5902122346
#   Asteroid ID: 54387387
#   Asteroid Name: (2023 SU6)
#   The Minimal estimated diameter (kilometers): 0.099667824
#   Absolute_magnitude (H): 22.13
#   Relative Velocity (km/h): 58700.0080920024
#   Asteroid ID: 54390659
#   Asteroid Name: (2023 TG)
#   The Minimal estimated diameter (kilometers): 0.0061172324
#   Absolute_magnitude (H): 28.19
#   Relative Velocity (km/h): 26007.4676296903
#   Asteroid ID: 54390821
#   Asteroid Name: (2023 TQ)
#   The Minimal estimated diameter (kilometers): 0.0192555078
#   Absolute_magnitude (H): 25.7
#   Relative Velocity (km/h): 47607.6430175998
#   Asteroid ID: 54390822
#   Asteroid Name: (2023 TU)
#   The Minimal estimated diameter (kilometers): 0.0066153828
#   Absolute_magnitude (H): 28.02
#   Relative Velocity (km/h): 29477.603301614
#   Asteroid ID: 54392066
#   Asteroid Name: (2023 TL3)
#   The Minimal estimated diameter (kilometers): 0.0220067027
#   Absolute_magnitude (H): 25.41
#   Relative Velocity (km/h): 58302.719098052
#   Asteroid ID: 54392069
#   Asteroid Name: (2023 TO3)
#   The Minimal estimated diameter (kilometers): 0.0073207399
#   Absolute_magnitude (H): 27.8
#   Relative Velocity (km/h): 49283.818026511
#   Asteroid ID: 54392644
#   Asteroid Name: (2023 TA6)
#   The Minimal estimated diameter (kilometers): 0.0110294785
#   Absolute_magnitude (H): 26.91
#   Relative Velocity (km/h): 35619.2638442259
#   Asteroid ID: 54393141
#   Asteroid Name: (2023 TY8)
#   The Minimal estimated diameter (kilometers): 0.0169260249
#   Absolute_magnitude (H): 25.98
#   Relative Velocity (km/h): 51384.2280592626
#   Asteroid ID: 54393160
#   Asteroid Name: (2023 TJ10)
#   The Minimal estimated diameter (kilometers): 0.0353634784
#   Absolute_magnitude (H): 24.38
#   Relative Velocity (km/h): 49797.435049983
#   Asteroid ID: 54400050
#   Asteroid Name: (2023 US9)
#   The Minimal estimated diameter (kilometers): 0.0557898221
#   Absolute_magnitude (H): 23.39
#   Relative Velocity (km/h): 31485.178277658
#   Asteroid ID: 54404088
#   Asteroid Name: (2023 VT5)
#   The Minimal estimated diameter (kilometers): 0.0592318063
#   Absolute_magnitude (H): 23.26
#   Relative Velocity (km/h): 22533.4808070511
#   Asteroid ID: 54404383
#   Asteroid Name: (2023 VS6)
#   The Minimal estimated diameter (kilometers): 0.1375798959
#   Absolute_magnitude (H): 21.43
#   Relative Velocity (km/h): 43849.6821036288
#   Asteroid ID: 54476945
#   Asteroid Name: (2024 RO43)
#   The Minimal estimated diameter (kilometers): 0.0296862251
#   Absolute_magnitude (H): 24.76
#   Relative Velocity (km/h): 44651.7134534905
#   Asteroid ID: 54486929
#   Asteroid Name: (2024 TT)
#   The Minimal estimated diameter (kilometers): 0.0081386988
#   Absolute_magnitude (H): 27.57
#   Relative Velocity (km/h): 40595.463843007
#   Asteroid ID: 54486931
#   Asteroid Name: (2024 TW)
#   The Minimal estimated diameter (kilometers): 0.0043107712
#   Absolute_magnitude (H): 28.95
#   Relative Velocity (km/h): 35181.7602016368
#   Asteroid ID: 54488497
#   Asteroid Name: (2024 TL5)
#   The Minimal estimated diameter (kilometers): 0.0080640828
#   Absolute_magnitude (H): 27.59
#   Relative Velocity (km/h): 26651.2179575494
# Date: 2023-10-07
#   Asteroid ID: 2162120
#   Asteroid Name: 162120 (1998 SH36)
#   The Minimal estimated diameter (kilometers): 0.1970402621
#   Absolute_magnitude (H): 20.65
#   Relative Velocity (km/h): 78884.3598651245
#   Asteroid ID: 2162162
#   Asteroid Name: 162162 (1999 DB7)
#   The Minimal estimated diameter (kilometers): 0.2670268771
#   Absolute_magnitude (H): 19.99
#   Relative Velocity (km/h): 30445.2715471926
#   Asteroid ID: 2503871
#   Asteroid Name: 503871 (2000 SL)
#   The Minimal estimated diameter (kilometers): 0.5950520786
#   Absolute_magnitude (H): 18.25
#   Relative Velocity (km/h): 68713.9029597006
#   Asteroid ID: 3293790
#   Asteroid Name: (2005 TQ45)
#   The Minimal estimated diameter (kilometers): 0.0201629919
#   Absolute_magnitude (H): 25.6
#   Relative Velocity (km/h): 64279.6848773327
#   Asteroid ID: 3645193
#   Asteroid Name: (2013 OY3)
#   The Minimal estimated diameter (kilometers): 0.0294140602
#   Absolute_magnitude (H): 24.78
#   Relative Velocity (km/h): 43439.7825681304
#   Asteroid ID: 3742876
#   Asteroid Name: (2016 CF137)
#   The Minimal estimated diameter (kilometers): 0.0184737464
#   Absolute_magnitude (H): 25.79
#   Relative Velocity (km/h): 26872.0523571043
#   Asteroid ID: 3844011
#   Asteroid Name: (2019 SS2)
#   The Minimal estimated diameter (kilometers): 0.0019255508
#   Absolute_magnitude (H): 30.7
#   Relative Velocity (km/h): 72809.5881971171
#   Asteroid ID: 3869331
#   Asteroid Name: (2019 SB6)
#   The Minimal estimated diameter (kilometers): 0.0117099483
#   Absolute_magnitude (H): 26.78
#   Relative Velocity (km/h): 20658.3380773169
#   Asteroid ID: 3872637
#   Asteroid Name: (2019 SL8)
#   The Minimal estimated diameter (kilometers): 0.0175612318
#   Absolute_magnitude (H): 25.9
#   Relative Velocity (km/h): 41590.5425737272
#   Asteroid ID: 3884015
#   Asteroid Name: (2019 UY8)
#   The Minimal estimated diameter (kilometers): 0.0270741591
#   Absolute_magnitude (H): 24.96
#   Relative Velocity (km/h): 34209.3792706814
#   Asteroid ID: 54087855
#   Asteroid Name: (2020 VU5)
#   The Minimal estimated diameter (kilometers): 0.0088014652
#   Absolute_magnitude (H): 27.4
#   Relative Velocity (km/h): 26473.5405589816
#   Asteroid ID: 54169406
#   Asteroid Name: (2021 NQ5)
#   The Minimal estimated diameter (kilometers): 0.1579628558
#   Absolute_magnitude (H): 21.13
#   Relative Velocity (km/h): 33352.9512895324
#   Asteroid ID: 54208043
#   Asteroid Name: (2021 TS10)
#   The Minimal estimated diameter (kilometers): 0.0203495578
#   Absolute_magnitude (H): 25.58
#   Relative Velocity (km/h): 50241.226823662
#   Asteroid ID: 54312823
#   Asteroid Name: (2022 TD)
#   The Minimal estimated diameter (kilometers): 0.0075605776
#   Absolute_magnitude (H): 27.73
#   Relative Velocity (km/h): 33847.6216619477
#   Asteroid ID: 54335221
#   Asteroid Name: (2022 YL)
#   The Minimal estimated diameter (kilometers): 0.0133830462
#   Absolute_magnitude (H): 26.49
#   Relative Velocity (km/h): 21446.4225794407
#   Asteroid ID: 54356387
#   Asteroid Name: (2023 HH4)
#   The Minimal estimated diameter (kilometers): 0.1063053145
#   Absolute_magnitude (H): 21.99
#   Relative Velocity (km/h): 45432.5899794336
#   Asteroid ID: 54382563
#   Asteroid Name: (2023 RN7)
#   The Minimal estimated diameter (kilometers): 0.061738344
#   Absolute_magnitude (H): 23.17
#   Relative Velocity (km/h): 41085.0423589133
#   Asteroid ID: 54386474
#   Asteroid Name: (2023 RR29)
#   The Minimal estimated diameter (kilometers): 0.0290104841
#   Absolute_magnitude (H): 24.81
#   Relative Velocity (km/h): 29211.5806785765
#   Asteroid ID: 54389194
#   Asteroid Name: (2023 SG7)
#   The Minimal estimated diameter (kilometers): 0.0494942761
#   Absolute_magnitude (H): 23.65
#   Relative Velocity (km/h): 46471.9019733742
#   Asteroid ID: 54390663
#   Asteroid Name: (2023 TK)
#   The Minimal estimated diameter (kilometers): 0.0101054342
#   Absolute_magnitude (H): 27.1
#   Relative Velocity (km/h): 17621.9540819049
#   Asteroid ID: 54390827
#   Asteroid Name: (2023 TX)
#   The Minimal estimated diameter (kilometers): 0.0031085294
#   Absolute_magnitude (H): 29.66
#   Relative Velocity (km/h): 25194.8247084796
#   Asteroid ID: 54391006
#   Asteroid Name: (2023 TB1)
#   The Minimal estimated diameter (kilometers): 0.0036690614
#   Absolute_magnitude (H): 29.3
#   Relative Velocity (km/h): 33683.9236894056
#   Asteroid ID: 54391008
#   Asteroid Name: (2023 TD1)
#   The Minimal estimated diameter (kilometers): 0.010012787
#   Absolute_magnitude (H): 27.12
#   Relative Velocity (km/h): 62871.5404799878
#   Asteroid ID: 54391014
#   Asteroid Name: (2023 TK1)
#   The Minimal estimated diameter (kilometers): 0.04493192
#   Absolute_magnitude (H): 23.86
#   Relative Velocity (km/h): 41585.713532708
#   Asteroid ID: 54391017
#   Asteroid Name: (2023 TN1)
#   The Minimal estimated diameter (kilometers): 0.0363542322
#   Absolute_magnitude (H): 24.32
#   Relative Velocity (km/h): 45674.1694892074
#   Asteroid ID: 54391021
#   Asteroid Name: (2023 TR1)
#   The Minimal estimated diameter (kilometers): 0.0028612445
#   Absolute_magnitude (H): 29.84
#   Relative Velocity (km/h): 71920.5854816282
#   Asteroid ID: 54391026
#   Asteroid Name: (2023 TX1)
#   The Minimal estimated diameter (kilometers): 0.0251509837
#   Absolute_magnitude (H): 25.12
#   Relative Velocity (km/h): 23626.9013832226
#   Asteroid ID: 54392415
#   Asteroid Name: (2023 TJ4)
#   The Minimal estimated diameter (kilometers): 0.0035526709
#   Absolute_magnitude (H): 29.37
#   Relative Velocity (km/h): 45193.2092473385
#   Asteroid ID: 54392416
#   Asteroid Name: (2023 TK4)
#   The Minimal estimated diameter (kilometers): 0.004814542
#   Absolute_magnitude (H): 28.71
#   Relative Velocity (km/h): 51235.9751810563
#   Asteroid ID: 54396404
#   Asteroid Name: (2023 TD32)
#   The Minimal estimated diameter (kilometers): 0.0199781365
#   Absolute_magnitude (H): 25.62
#   Relative Velocity (km/h): 55094.9800232815
#   Asteroid ID: 54395885
#   Asteroid Name: (2023 UR)
#   The Minimal estimated diameter (kilometers): 0.0345585074
#   Absolute_magnitude (H): 24.43
#   Relative Velocity (km/h): 34444.8165356355
#   Asteroid ID: 54417658
#   Asteroid Name: (2023 YX)
#   The Minimal estimated diameter (kilometers): 0.057089334
#   Absolute_magnitude (H): 23.34
#   Relative Velocity (km/h): 21855.9217934006
#   Asteroid ID: 54430775
#   Asteroid Name: (2024 EF4)
#   The Minimal estimated diameter (kilometers): 0.0427124985
#   Absolute_magnitude (H): 23.97
#   Relative Velocity (km/h): 40857.3111364045
#   Asteroid ID: 2679885
#   Asteroid Name: 679885 (2021 NQ5)
#   The Minimal estimated diameter (kilometers): 0.1572370824
#   Absolute_magnitude (H): 21.14
#   Relative Velocity (km/h): 33352.9516519513

# %%
# put the data in a pandas dataframe to make it easier to manipulate and analyze the data
rows = []

# Loop through the data and collect rows in a list
for date, asteroids in data_astr['near_earth_objects'].items():
    for asteroid in asteroids:
        rows.append({
            'Asteroid ID': asteroid['id'],
            'Asteroid Name': asteroid['name'],
            'The Minimal estimated diameter (kilometers)' : asteroid['estimated_diameter']['kilometers']['estimated_diameter_min'],
            'Absolute_magnitude (H)': asteroid['absolute_magnitude_h'],
            'Relative Velocity (km/h)': asteroid['close_approach_data'][0]['relative_velocity']['kilometers_per_hour'],
        })

# Create the DataFrame from the list of rows
df = pd.DataFrame(rows)

# %%
#display the first 10 rows of the dataframe
df.head(10)
# Out:
#   Asteroid ID       Asteroid Name  \
# 0     2137084  137084 (1998 XS16)
# 1     2252399  252399 (2001 TX44)
# 2     3342645          (2006 SG7)
# 3     3451020          (2009 EG3)
# 4     3606252           (2012 OO)
# 5     3740047        (2016 AM165)
# 6     3888755         (2019 UQ12)
# 7    54016425          (2020 FW6)
# 8    54016634          (2020 HO2)
# 9    54217963          (2021 VA6)
#
#    The Minimal estimated diameter (kilometers)  Absolute_magnitude (H)  \
# 0                                     1.344482                   16.48
# 1                                     0.348783                   19.41
# 2                                     0.071871                   22.84
# 3                                     0.145397                   21.31
# 4                                     0.197950                   20.64
# 5                                     0.030518                   24.70
# 6                                     0.046191                   23.80
# 7                                     0.060333                   23.22
# 8                                     0.036691                   24.30
# 9                                     0.004514                   28.85
#
#   Relative Velocity (km/h)
# 0         64873.2160143983
# 1          47425.552833141
# 2          40346.826106311
# 3         71098.0109047015
# 4         33991.7291708756
# 5         21746.7219087179
# 6         64516.5575776706
# 7         46657.9212968621
# 8         45466.0186505674
# 9         31894.7763409622

# %%
# Export the DataFrame to a CSV file
df.to_csv('asteroids_data.csv', index=False)
